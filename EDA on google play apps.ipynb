# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('google play.csv')
df.head(5)
# Out:
#                                             App Name  \
# 0                             HTTrack Website Copier
# 1                      World War 2: Offline Strategy
# 2                                             WPSApp
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...
# 4                                   Loud Player Free
#
#                      App Id       Category  Rating  Rating Count  \
# 0       com.httrack.android  Communication     3.6        2848.0
# 1           com.skizze.wwii       Strategy     4.3       17297.0
# 2     com.themausoft.wpsapp          Tools     4.2      488639.0
# 3    com.mobisystems.office       Business     4.2     1224420.0
# 4  com.arthelion.loudplayer  Music & Audio     4.2         665.0
#
#        Installs  Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0      100,000+          100000.0            351560  True    0.0  ...
# 1    1,000,000+         1000000.0           2161778  True    0.0  ...
# ...

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice'],
#       dtype='object')

# %%
df.shape
# Out:
# (1118136, 23)

# %%
df.drop(['Developer Id', 'Developer Website',
       'Developer Email'], inplace = True, axis=1)

# %%
df.drop(['App Id','Privacy Policy'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                             App Name       Category  Rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    Rating Count      Installs  Minimum Installs  Maximum Installs  Free  \
# 0        2848.0      100,000+          100000.0            351560  True
# 1       17297.0    1,000,000+         1000000.0           2161778  True
# 2      488639.0   50,000,000+        50000000.0          79304739  True
# 3     1224420.0  100,000,000+       100000000.0         163660067  True
# 4         665.0       50,000+           50000.0             73463  True
#
#    Price Currency  Size Minimum Android      Released  Last Updated  \
# ...

# %%
df.head()
# Out:
#                                             App Name       Category  Rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    Rating Count      Installs  Minimum Installs  Maximum Installs  Free  \
# 0        2848.0      100,000+          100000.0            351560  True
# 1       17297.0    1,000,000+         1000000.0           2161778  True
# 2      488639.0   50,000,000+        50000000.0          79304739  True
# 3     1224420.0  100,000,000+       100000000.0         163660067  True
# 4         665.0       50,000+           50000.0             73463  True
#
#    Price Currency  Size Minimum Android      Released  Last Updated  \
# ...

# %%
df.isnull().sum()
# Out:
# App Name               1
# Category               3
# Rating              6850
# Rating Count        6850
# Installs             161
# Minimum Installs     161
# Maximum Installs       0
# Free                   0
# Price                  0
# Currency             161
# Size                   0
# Minimum Android     2013
# Released            7730
# Last Updated           0
# Content Rating         0
# Ad Supported           0
# In App Purchases       0
# Editors Choice         0
# dtype: int64

# %%
df[df['Category'].isna()]
# Out:
#                           App Name Category  Rating  Rating Count  Installs  \
# 677266            Colorful Peacock      NaN     4.4        1066.0  100,000+
# 677356  Neon Skulls Live Wallpaper      NaN     4.3          59.0    5,000+
# 677951                     AttendO      NaN     5.0          66.0      100+
#
#         Minimum Installs  Maximum Installs  Free  Price Currency  Size  \
# 677266          100000.0            227680  True    0.0      USD  4.1M
# 677356            5000.0              7544  True    0.0      USD  1.5M
# 677951             100.0               325  True    0.0      XXX   11M
#
#        Minimum Android      Released  Last Updated Content Rating  \
# 677266    4.0.3 and up   Sep 7, 2016  Feb 18, 2020       Everyone
# 677356      4.0 and up   Mar 2, 2015  Oct 30, 2020   Everyone 10+
# 677951      5.0 and up  Sep 25, 2020  Nov 12, 2020       Everyone
#
#         Ad Supported  In App Purchases  Editors Choice
# ...

# %%
a = df[df['App Name'] == 'Colorful Peacock'].fillna('Personalization')
a
# Out:
#                 App Name         Category  Rating  Rating Count  Installs  \
# 677266  Colorful Peacock  Personalization     4.4        1066.0  100,000+
#
#         Minimum Installs  Maximum Installs  Free  Price Currency  Size  \
# 677266          100000.0            227680  True    0.0      USD  4.1M
#
#        Minimum Android     Released  Last Updated Content Rating  \
# 677266    4.0.3 and up  Sep 7, 2016  Feb 18, 2020       Everyone
#
#         Ad Supported  In App Purchases  Editors Choice
# 677266          True             False           False

# %%
b = df[df['App Name'] == 'Neon Skulls Live Wallpaper'].fillna('Personalization')
b
# Out:
#                           App Name         Category  Rating  Rating Count  \
# 677356  Neon Skulls Live Wallpaper  Personalization     4.3          59.0
#
#        Installs  Minimum Installs  Maximum Installs  Free  Price Currency  \
# 677356   5,000+            5000.0              7544  True    0.0      USD
#
#         Size Minimum Android     Released  Last Updated Content Rating  \
# 677356  1.5M      4.0 and up  Mar 2, 2015  Oct 30, 2020   Everyone 10+
#
#         Ad Supported  In App Purchases  Editors Choice
# 677356          True             False           False

# %%
c = df[df['App Name'] == 'AttendO'].fillna('Productivity')
c
# Out:
#        App Name      Category  Rating  Rating Count Installs  \
# 677951  AttendO  Productivity     5.0          66.0     100+
#
#         Minimum Installs  Maximum Installs  Free  Price Currency Size  \
# 677951             100.0               325  True    0.0      XXX  11M
#
#        Minimum Android      Released  Last Updated Content Rating  \
# 677951      5.0 and up  Sep 25, 2020  Nov 12, 2020       Everyone
#
#         Ad Supported  In App Purchases  Editors Choice
# 677951         False             False           False

# %%
df['Category'].unique()
# Out:
# array(['Communication', 'Strategy', 'Tools', 'Business', 'Music & Audio',
#        'Maps & Navigation', 'Lifestyle', 'Educational', 'Productivity',
#        'News & Magazines', 'Food & Drink', 'Photography',
#        'Books & Reference', 'Shopping', 'Board', 'Sports', 'Medical',
#        'Health & Fitness', 'House & Home', 'Education', 'Auto & Vehicles',
#        'Finance', 'Parenting', 'Travel & Local', 'Personalization',
#        'Entertainment', 'Video Players & Editors', 'Puzzle', 'Casual',
#        'Events', 'Arcade', 'Music', 'Trivia', 'Action', 'Simulation',
#        'Racing', 'Weather', 'Role Playing', 'Adventure', 'Social', 'Word',
#        'Comics', 'Art & Design', 'Card', 'Libraries & Demo', 'Casino',
#        'Beauty', 'Dating', nan], dtype=object)

# %%
df = df.drop(df[df['App Name'] =='Colorful Peacock'].index, axis=0)

# %%
df = df.drop(df[df['App Name'] =='Neon Skulls Live Wallpaper'].index, axis=0)

# %%
df = df.drop(df[df['App Name'] =='AttendO'].index, axis=0)

# %%
df = pd.concat([df,a], axis=0)

# %%
df = pd.concat([df,b], axis=0)

# %%
df = pd.concat([df,c], axis=0)

# %%
df.shape
# Out:
# (1118136, 18)

# %%
df = df.reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# App Name               1
# Category               0
# Rating              6850
# Rating Count        6850
# Installs             161
# Minimum Installs     161
# Maximum Installs       0
# Free                   0
# Price                  0
# Currency             161
# Size                   0
# Minimum Android     2013
# Released            7730
# Last Updated           0
# Content Rating         0
# Ad Supported           0
# In App Purchases       0
# Editors Choice         0
# dtype: int64

# %%
d = round(df['Rating'].mean(),0)

# %%
df['Rating'] = df['Rating'].fillna(d)

# %%
e = round(df['Rating Count'].mean(),0)

# %%
df['Rating Count'] = df['Rating Count'].fillna(e)

# %%
df.isnull().sum()
# Out:
# App Name               1
# Category               0
# Rating                 0
# Rating Count           0
# Installs             161
# Minimum Installs     161
# Maximum Installs       0
# Free                   0
# Price                  0
# Currency             161
# Size                   0
# Minimum Android     2013
# Released            7730
# Last Updated           0
# Content Rating         0
# Ad Supported           0
# In App Purchases       0
# Editors Choice         0
# dtype: int64

# %%
df['Installs'].mode()[0]
# Out:
# '1,000+'

# %%
df.loc[df['Installs'].isna()]
# Out:
#                                                  App Name       Category  \
# 1019     Bouncy Bird: Casual & Relaxing Flappy Style Game         Casual
# 1165         Dangerous Shelter - Your Life is Your Choice     Simulation
# 1706                                      Diablo Immortal   Role Playing
# 1957                                               Fer.al   Role Playing
# 4470                                           Sense Chat  Communication
# ...                                                   ...            ...
# 1083012                                  Fairy tales Book      Education
# 1089485                      Wallace & Gromit: Big Fix Up  Entertainment
# 1099485                          Heroes II - Bible Trivia         Trivia
# 1100902                                      Space Jumper         Arcade
# 1108817                        Tebak Gambar Sayuran Sehat    Educational
#
#          Rating  Rating Count Installs  Minimum Installs  Maximum Installs  \
# ...

# %%
df = df.drop(df[df['Installs'].isna()].index, axis=0)

# %%
df.isnull().sum()
# Out:
# App Name               1
# Category               0
# Rating                 0
# Rating Count           0
# Installs               0
# Minimum Installs       0
# Maximum Installs       0
# Free                   0
# Price                  0
# Currency               0
# Size                   0
# Minimum Android     2013
# Released            7569
# Last Updated           0
# Content Rating         0
# Ad Supported           0
# In App Purchases       0
# Editors Choice         0
# dtype: int64

# %%
df['Installs'] = df['Installs'].apply(lambda x : int(x.replace('+','').replace(',','')))

# %%
df.head()
# Out:
#                                             App Name       Category  Rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    Rating Count   Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0        2848.0     100000          100000.0            351560  True    0.0
# 1       17297.0    1000000         1000000.0           2161778  True    0.0
# 2      488639.0   50000000        50000000.0          79304739  True    0.0
# 3     1224420.0  100000000       100000000.0         163660067  True    0.0
# 4         665.0      50000           50000.0             73463  True    0.0
#
# ...

# %%
df['Rating Count'] = df['Rating Count'].astype('int64')

# %%
df.dtypes
# Out:
# App Name             object
# Category             object
# Rating              float64
# Rating Count          int64
# Installs              int64
# Minimum Installs    float64
# Maximum Installs      int64
# Free                   bool
# Price               float64
# Currency             object
# Size                 object
# Minimum Android      object
# Released             object
# Last Updated         object
# Content Rating       object
# Ad Supported           bool
# In App Purchases       bool
# Editors Choice         bool
# dtype: object

# %%
df['Minimum Installs'] = df['Minimum Installs'].astype('int64')

# %%
df.head()
# Out:
#                                             App Name       Category  Rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    Rating Count   Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0          2848     100000            100000            351560  True    0.0
# 1         17297    1000000           1000000           2161778  True    0.0
# 2        488639   50000000          50000000          79304739  True    0.0
# 3       1224420  100000000         100000000         163660067  True    0.0
# 4           665      50000             50000             73463  True    0.0
#
# ...

# %%
df['Currency'].unique()
# Out:
# array(['USD', 'XXX', 'EUR', 'RUB', 'ILS', 'VND', 'JPY', 'ZAR', 'LBP',
#        'AUD', 'TWD', 'HKD', 'UAH', 'SEK', 'KRW', 'PKR', 'INR', 'CZK',
#        'CAD', 'MXN', 'TRY', 'KZT', 'GBP', 'SGD', 'IDR', 'DZD', 'AED',
#        'PLN', 'CHF', 'THB', 'BGN', 'SAR', 'DKK', 'NGN', 'BDT', 'NOK',
#        'HUF', 'KES', 'LKR', 'NZD', 'RSD', 'MYR', 'BRL', 'COP', 'PEN',
#        'HRK', 'BOB', 'CRC', 'PHP', 'EGP', 'GHS', 'CLP', 'TZS', 'RON'],
#       dtype=object)

# %%
df.loc[df['Currency'] == 'XXX']
# Out:
#                                 App Name          Category  Rating  \
# 276       IE Radio - Irish Online Radios     Music & Audio     0.0
# 895      Yahoo Lite - News, Mail, Sports  News & Magazines     0.0
# 958        Hidden Cats: Detective Agency            Puzzle     2.0
# 1038                        Force Master            Arcade     4.0
# 1164                   A Sloth's Journey            Casual     4.5
# ...                                  ...               ...     ...
# 1118079                    SPX FLOW Sync          Business     0.0
# 1118110                    Basir Telecom     Communication     0.0
# 1118111                       Br-Madeena     Communication     0.0
# 1118112                      ASRAFUL TEL     Communication     0.0
# 1118135                          AttendO      Productivity     5.0
#
#          Rating Count  Installs  Minimum Installs  Maximum Installs  Free  \
# 276                 0         1                 1                 1  True
# ...

# %%
df = df.drop('Currency', axis=1)

# %%
df.head()
# Out:
#                                             App Name       Category  Rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    Rating Count   Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0          2848     100000            100000            351560  True    0.0
# 1         17297    1000000           1000000           2161778  True    0.0
# 2        488639   50000000          50000000          79304739  True    0.0
# 3       1224420  100000000         100000000         163660067  True    0.0
# 4           665      50000             50000             73463  True    0.0
#
# ...

# %%
df.drop('Minimum Installs', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                             App Name       Category  Rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    Rating Count   Installs  Maximum Installs  Free  Price  Size  \
# 0          2848     100000            351560  True    0.0  2.7M
# 1         17297    1000000           2161778  True    0.0   86M
# 2        488639   50000000          79304739  True    0.0  5.8M
# 3       1224420  100000000         163660067  True    0.0   59M
# 4           665      50000             73463  True    0.0   29M
#
#   Minimum Android      Released  Last Updated Content Rating  Ad Supported  \
# ...

# %%
df['Minimum Android'] = df['Minimum Android'].fillna(df['Minimum Android'].mode()[0])

# %%
df['Minimum Android'] = df['Minimum Android'].apply(lambda x : (x.replace('and up', '')))

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Everyone 10+', 'Teen', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
df['Content Rating'] = df['Content Rating'].astype('category')

# %%
df['Category'] = df['Category'].astype('category')

# %%
df.dtypes
# Out:
# App Name              object
# Category            category
# Rating               float64
# Rating Count           int64
# Installs               int64
# Maximum Installs       int64
# Free                    bool
# Price                float64
# Size                  object
# Minimum Android       object
# Released              object
# Last Updated          object
# Content Rating      category
# Ad Supported            bool
# In App Purchases        bool
# Editors Choice          bool
# dtype: object

# %%
df['Size'] = df['Size'].apply(lambda x : x.replace(",",""))

# %%
df.isnull().sum()
# Out:
# App Name               1
# Category               0
# Rating                 0
# Rating Count           0
# Installs               0
# Maximum Installs       0
# Free                   0
# Price                  0
# Size                   0
# Minimum Android        0
# Released            7569
# Last Updated           0
# Content Rating         0
# Ad Supported           0
# In App Purchases       0
# Editors Choice         0
# dtype: int64

# %%
df.tail(20)
# Out:
#                               App Name         Category  Rating  Rating Count  \
# 1118116           BOSS Home Appliances         Shopping     4.2            10
# 1118117                Demo School App        Education     0.0             0
# 1118118             Shree Kripa Motors     Productivity     0.0             0
# 1118119                Shree Sen Samaj           Social     4.6            36
# 1118120                      Tata Bata         Shopping     0.0             0
# 1118121                        Luncher     Productivity     2.0          5160
# 1118122                    AT INFINITI     Productivity     0.0             0
# 1118123                          HANWA        Lifestyle     0.0             0
# 1118124                      TGIF 2018        Education     0.0             0
# 1118125               Asset Management         Business     2.0          5160
# 1118126  Campaign Blaster Yuge Edition           Casual     0.0             0
# ...

# %%
def clean_size_column(x):
    if 'M' in x:
        return float(x.replace('M',''))
    elif 'Varies with device' in x:
        return 'Varies with device'
    elif 'k' in x:
        return (float(x.replace('k',''))/1000)
    elif 'G' in x:
        return (float(x.replace('G',''))*1000)
        
df['Size'] = df['Size'].apply(clean_size_column)

# %%
df.tail(20)
# Out:
#                               App Name         Category  Rating  Rating Count  \
# 1118116           BOSS Home Appliances         Shopping     4.2            10
# 1118117                Demo School App        Education     0.0             0
# 1118118             Shree Kripa Motors     Productivity     0.0             0
# 1118119                Shree Sen Samaj           Social     4.6            36
# 1118120                      Tata Bata         Shopping     0.0             0
# 1118121                        Luncher     Productivity     2.0          5160
# 1118122                    AT INFINITI     Productivity     0.0             0
# 1118123                          HANWA        Lifestyle     0.0             0
# 1118124                      TGIF 2018        Education     0.0             0
# 1118125               Asset Management         Business     2.0          5160
# 1118126  Campaign Blaster Yuge Edition           Casual     0.0             0
# ...

# %%
df1 = df.loc[df['Size'] == 'Varies with device']

# %%
df1.shape
# Out:
# (37131, 16)

# %%
df1.head()
# Out:
#                                             App Name           Category  \
# 13                                     Google Slides       Productivity
# 17                                          Snapseed        Photography
# 25    LibreOffice & OpenOffice document reader | ODF       Productivity
# 26  All PDF - PDF Reader, PDF Viewer & PDF Converter  Books & Reference
# 27                     Docs To Go™ Free Office Suite           Business
#
#     Rating  Rating Count   Installs  Maximum Installs  Free  Price  \
# 13     4.2        448679  500000000         800199122  True    0.0
# 17     4.5       1281438  100000000         181354482  True    0.0
# 25     3.9         31881    5000000           6709911  True    0.0
# 26     4.2          9281     500000            904096  True    0.0
# 27     4.2        226610   50000000          70125112  True    0.0
#
#                   Size     Minimum Android      Released  Last Updated  \
# ...

# %%
df = df.drop(df[(df['Size'] == 'Varies with device') & (df['Minimum Android'] == 'Varies with device')].index, axis=0)

# %%
df.isnull().sum()
# Out:
# App Name              1
# Category              0
# Rating                0
# Rating Count          0
# Installs              0
# Maximum Installs      0
# Free                  0
# Price                 0
# Size                  0
# Minimum Android       0
# Released            968
# Last Updated          0
# Content Rating        0
# Ad Supported          0
# In App Purchases      0
# Editors Choice        0
# dtype: int64

# %%
df1 = df.loc[df['Size'] == 'Varies with device']
df1.shape
# Out:
# (16563, 16)

# %%
df.head()
# Out:
#                                             App Name       Category  Rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    Rating Count   Installs  Maximum Installs  Free  Price Size  \
# 0          2848     100000            351560  True    0.0  2.7
# 1         17297    1000000           2161778  True    0.0   86
# 2        488639   50000000          79304739  True    0.0  5.8
# 3       1224420  100000000         163660067  True    0.0   59
# 4           665      50000             73463  True    0.0   29
#
#   Minimum Android      Released  Last Updated Content Rating  Ad Supported  \
# ...

# %%
g = df['Minimum Android'].mode()[0]

# %%
df['Minimum Android'] = df['Minimum Android'].replace({'Varies with device':g})

# %%
h = df['Size'].mode()[0]
h
# Out:
# 11.0

# %%
df['Size'] = df['Size'].replace({'Varies with device':h})

# %%
df = df.drop(df[df['Released'].isna()].index, axis=0)

# %%
df.shape
# Out:
# (1096439, 16)

# %%
df.isnull().sum()
# Out:
# App Name            1
# Category            0
# Rating              0
# Rating Count        0
# Installs            0
# Maximum Installs    0
# Free                0
# Price               0
# Size                0
# Minimum Android     0
# Released            0
# Last Updated        0
# Content Rating      0
# Ad Supported        0
# In App Purchases    0
# Editors Choice      0
# dtype: int64

# %%
df['Released'] = pd.to_datetime(df['Released'])
df['Last Updated'] = pd.to_datetime(df['Last Updated'])

# %%
df.head()
# Out:
#                                             App Name       Category  Rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    Rating Count   Installs  Maximum Installs  Free  Price  Size  \
# 0          2848     100000            351560  True    0.0   2.7
# 1         17297    1000000           2161778  True    0.0  86.0
# 2        488639   50000000          79304739  True    0.0   5.8
# 3       1224420  100000000         163660067  True    0.0  59.0
# 4           665      50000             73463  True    0.0  29.0
#
#   Minimum Android   Released Last Updated Content Rating  Ad Supported  \
# ...

# %%
df.dtypes
# Out:
# App Name                    object
# Category                  category
# Rating                     float64
# Rating Count                 int64
# Installs                     int64
# Maximum Installs             int64
# Free                          bool
# Price                      float64
# Size                       float64
# Minimum Android             object
# Released            datetime64[ns]
# Last Updated        datetime64[ns]
# Content Rating            category
# Ad Supported                  bool
# In App Purchases              bool
# Editors Choice                bool
# dtype: object

# %%
df['Released Month'] = df['Released'].dt.month
df['Released Year'] = df['Released'].dt.year

# %%
df.head()
# Out:
#                                             App Name       Category  Rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    Rating Count   Installs  Maximum Installs  Free  Price  Size  \
# 0          2848     100000            351560  True    0.0   2.7
# 1         17297    1000000           2161778  True    0.0  86.0
# 2        488639   50000000          79304739  True    0.0   5.8
# 3       1224420  100000000         163660067  True    0.0  59.0
# 4           665      50000             73463  True    0.0  29.0
#
#   Minimum Android   Released Last Updated Content Rating  Ad Supported  \
# ...

# %%
df['Last Updated Month'] = df['Last Updated'].dt.month
df['Last Updated Year'] = df['Last Updated'].dt.year

# %%
df['Last Updated Month'] = df['Last Updated Month'].astype('category')
df['Last Updated Year'] = df['Last Updated Year'].astype('category')
df['Released Month'] = df['Released Month'].astype('category')
df['Released Year'] = df['Released Year'].astype('category')

# %%
df.dtypes
# Out:
# App Name                      object
# Category                    category
# Rating                       float64
# Rating Count                   int64
# Installs                       int64
# Maximum Installs               int64
# Free                            bool
# Price                        float64
# Size                         float64
# Minimum Android               object
# Released              datetime64[ns]
# Last Updated          datetime64[ns]
# Content Rating              category
# Ad Supported                    bool
# In App Purchases                bool
# Editors Choice                  bool
# Released Month              category
# Released Year               category
# Last Updated Month          category
# Last Updated Year           category
# dtype: object

# %%
df['Days Difference'] = df['Last Updated'] - df['Released']

# %%
df = df.drop(['Released','Last Updated'], axis=1)

# %%
df.head()
# Out:
#                                             App Name       Category  Rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    Rating Count   Installs  Maximum Installs  Free  Price  Size  \
# 0          2848     100000            351560  True    0.0   2.7
# 1         17297    1000000           2161778  True    0.0  86.0
# 2        488639   50000000          79304739  True    0.0   5.8
# 3       1224420  100000000         163660067  True    0.0  59.0
# 4           665      50000             73463  True    0.0  29.0
#
#   Minimum Android Content Rating  Ad Supported  In App Purchases  \
# ...

# %%
df['Days Difference'] = df['Days Difference'].astype('str')

# %%
df['days_difference'] = df['Days Difference'].apply(lambda x:x.replace('days', ''))

# %%
df = df.drop('Days Difference', axis=1)

# %%
df.head()
# Out:
#                                             App Name       Category  Rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    Rating Count   Installs  Maximum Installs  Free  Price  Size  \
# 0          2848     100000            351560  True    0.0   2.7
# 1         17297    1000000           2161778  True    0.0  86.0
# 2        488639   50000000          79304739  True    0.0   5.8
# 3       1224420  100000000         163660067  True    0.0  59.0
# 4           665      50000             73463  True    0.0  29.0
#
#   Minimum Android Content Rating  Ad Supported  In App Purchases  \
# ...

# %%
df.columns = ['_'.join(col.split(" ")).lower() for col in df.columns.tolist()]

# %%
df.head()
# Out:
#                                             app_name       category  rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    rating_count   installs  maximum_installs  free  price  size  \
# 0          2848     100000            351560  True    0.0   2.7
# 1         17297    1000000           2161778  True    0.0  86.0
# 2        488639   50000000          79304739  True    0.0   5.8
# 3       1224420  100000000         163660067  True    0.0  59.0
# 4           665      50000             73463  True    0.0  29.0
#
#   minimum_android content_rating  ad_supported  in_app_purchases  \
# ...

# %%
plt.figure(figsize=(15,7))
sns.countplot(df['category'])
plt.xticks(rotation='90')
plt.show()
# Out:
# C:\Users\navnegup.CORP\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.dtypes
# Out:
# app_name                object
# category              category
# rating                 float64
# rating_count             int64
# installs                 int64
# maximum_installs         int64
# free                      bool
# price                  float64
# size                   float64
# minimum_android         object
# content_rating        category
# ad_supported              bool
# in_app_purchases          bool
# editors_choice            bool
# released_month        category
# released_year         category
# last_updated_month    category
# last_updated_year     category
# days_difference         object
# dtype: object

# %%
df['days_difference'] = df['days_difference'].astype('int64')

# %%
df.head()
# Out:
#                                             app_name       category  rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    rating_count   installs  maximum_installs  free  price  size  \
# 0          2848     100000            351560  True    0.0   2.7
# 1         17297    1000000           2161778  True    0.0  86.0
# 2        488639   50000000          79304739  True    0.0   5.8
# 3       1224420  100000000         163660067  True    0.0  59.0
# 4           665      50000             73463  True    0.0  29.0
#
#   minimum_android content_rating  ad_supported  in_app_purchases  \
# ...

# %%
df = df.drop(df[df['days_difference']<0].index, axis=0)

# %%
df.shape
# Out:
# (1093567, 19)

# %%
sns.countplot(df['released_year'])
# Out:
# C:\Users\navnegup.CORP\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='released_year', ylabel='count'>

# %%
sns.countplot(df['released_month'])
# Out:
# C:\Users\navnegup.CORP\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='released_month', ylabel='count'>

# %%
sns.countplot(df['last_updated_year'])
# Out:
# C:\Users\navnegup.CORP\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='last_updated_year', ylabel='count'>

# %%
sns.countplot(df['last_updated_month'])
# Out:
# C:\Users\navnegup.CORP\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='last_updated_month', ylabel='count'>

# %%
sns.countplot(df['editors_choice'])
# Out:
# C:\Users\navnegup.CORP\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='editors_choice', ylabel='count'>

# %%
df['editors_choice'].value_counts()
# Out:
# False    1092916
# True         651
# Name: editors_choice, dtype: int64

# %%
sns.countplot(df['in_app_purchases'])
# Out:
# C:\Users\navnegup.CORP\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='in_app_purchases', ylabel='count'>

# %%
sns.countplot(df['ad_supported'])
# Out:
# C:\Users\navnegup.CORP\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ad_supported', ylabel='count'>

# %%
sns.countplot(df['free'])
# Out:
# C:\Users\navnegup.CORP\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='free', ylabel='count'>

# %%
sns.countplot(df['content_rating'])
plt.xticks(rotation='90')
plt.show()
# Out:
# C:\Users\navnegup.CORP\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['content_rating'].value_counts()
# Out:
# Everyone           946917
# Teen                97714
# Mature 17+          31445
# Everyone 10+        17372
# Unrated                66
# Adults only 18+        53
# Name: content_rating, dtype: int64

# %%
df.corr()
# Out:
#                     rating  rating_count  installs  maximum_installs  \
# rating            1.000000      0.024265  0.028977          0.031010
# rating_count      0.024265      1.000000  0.490200          0.513428
# installs          0.028977      0.490200  1.000000          0.928694
# maximum_installs  0.031010      0.513428  0.928694          1.000000
# free              0.038252      0.004863  0.006972          0.007450
# price            -0.018170     -0.001387 -0.001947         -0.002082
# size              0.084190      0.043687  0.034433          0.036913
# ad_supported      0.097745      0.005262  0.005024          0.006200
# in_app_purchases  0.184840      0.053080  0.048566          0.052562
# editors_choice    0.021904      0.187130  0.098233          0.106208
# days_difference   0.312720      0.055978  0.061965          0.066457
#
#                       free     price      size  ad_supported  \
# rating            0.038252 -0.018170  0.084190      0.097745
# ...

# %%
df.drop('maximum_installs',axis=1,inplace=True )

# %%
df.head()
# Out:
#                                             app_name       category  rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    rating_count   installs  free  price  size minimum_android content_rating  \
# 0          2848     100000  True    0.0   2.7            2.3        Everyone
# 1         17297    1000000  True    0.0  86.0            5.1    Everyone 10+
# 2        488639   50000000  True    0.0   5.8            4.1        Everyone
# 3       1224420  100000000  True    0.0  59.0            4.4        Everyone
# 4           665      50000  True    0.0  29.0            5.0        Everyone
#
# ...

# %%
sns.scatterplot(y='price',x='rating', data=df)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='price'>

# %%
sns.scatterplot(y='rating_count',x='rating', data=df)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='rating_count'>

# %%
sns.scatterplot(y='installs',x='rating', data=df)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='installs'>

# %%
p = df.loc[df['free'] == False]

# %%
sns.scatterplot(x='rating',y='installs', data=p)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='installs'>

# %%
sns.scatterplot(y='size',x='rating', data=df)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='size'>

# %%
df['category'].value_counts().plot(kind='pie', autopct='%1.0f%%', pctdistance=0.9, radius=1.2,figsize=(20,20))
# Out:
# <AxesSubplot:ylabel='category'>

# %%
df['free'].value_counts().plot(kind='pie', autopct='%1.0f%%', pctdistance=0.8, radius=1.0,figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='free'>

# %%
df['content_rating'].value_counts().plot(kind='pie', autopct='%1.0f%%', pctdistance=0.8, radius=1.0,figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='content_rating'>

# %%
df.head()
# Out:
#                                             app_name       category  rating  \
# 0                             HTTrack Website Copier  Communication     3.6
# 1                      World War 2: Offline Strategy       Strategy     4.3
# 2                                             WPSApp          Tools     4.2
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...       Business     4.2
# 4                                   Loud Player Free  Music & Audio     4.2
#
#    rating_count   installs  free  price  size minimum_android content_rating  \
# 0          2848     100000  True    0.0   2.7            2.3        Everyone
# 1         17297    1000000  True    0.0  86.0            5.1    Everyone 10+
# 2        488639   50000000  True    0.0   5.8            4.1        Everyone
# 3       1224420  100000000  True    0.0  59.0            4.4        Everyone
# 4           665      50000  True    0.0  29.0            5.0        Everyone
#
# ...

# %%
df.groupby('category')['rating'].mean().sort_values(ascending=False).plot(kind='bar', figsize=(10,10))
plt.ylabel('Avg. rating')
plt.show()

# %%
df.groupby('category')['installs'].mean().sort_values(ascending=False).plot(kind='bar', figsize=(10,10))
plt.ylabel('Avg. installs')
plt.show()

# %%
df.groupby('category')['rating_count'].sum().sort_values(ascending=False).plot(kind='bar', figsize=(10,10))
plt.ylabel('Avg. rating count')
plt.show()

# %%
df.groupby('category')['size'].mean().sort_values(ascending=False).plot(kind='bar', figsize=(10,10))
plt.ylabel('Avg. size')
plt.show()
